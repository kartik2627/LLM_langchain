# %%
#ollama run gemma:2b
#ollama run gemma:70b
#ollama run llama3:70b
from  langchain_community.embeddings import OllamaEmbeddings    
embeddings = (OllamaEmbeddings(model="gemma:2b"))
embeddings
# Out:
# C:\Users\Karti\AppData\Local\Temp\ipykernel_17660\4173394611.py:5: LangChainDeprecationWarning: The class `OllamaEmbeddings` was deprecated in LangChain 0.3.1 and will be removed in 1.0.0. An updated version of the class exists in the `langchain-ollama package and should be used instead. To use it run `pip install -U `langchain-ollama` and import as `from `langchain_ollama import OllamaEmbeddings``.
#   embeddings = (OllamaEmbeddings(model="gemma:2b"))
# OllamaEmbeddings(base_url='http://localhost:11434', model='gemma:2b', embed_instruction='passage: ', query_instruction='query: ', mirostat=None, mirostat_eta=None, mirostat_tau=None, num_ctx=None, num_gpu=None, num_thread=None, repeat_last_n=None, repeat_penalty=None, temperature=None, stop=None, tfs_z=None, top_k=None, top_p=None, show_progress=False, headers=None, model_kwargs=None)

# %%
###Text  embeddings
R1 = embeddings.embed_documents(["hello world", "hi there"])
R1
# Out:
# [[-0.6397865414619446,
#   0.14209455251693726,
#   0.030178705230355263,
#   1.376239538192749,
#   2.0748074054718018,
#   0.2452269047498703,
#   -0.07082105427980423,
#   0.5383097529411316,
#   0.5919467210769653,
#   -1.1025606393814087,
#   0.16294115781784058,
#   0.7224851846694946,
#   -0.6075040102005005,
#   0.603295087814331,
#   -1.9165199995040894,
#   -0.6298832297325134,
#   1.6814121007919312,
#   -0.8940878510475159,
#   0.45337992906570435,
#   0.14762867987155914,
#   0.48397889733314514,
#   0.4252898693084717,
#   -3.004694700241089,
#   -0.9540703296661377,
#   -2.183791399002075,
#   0.3479580879211426,
#   -0.3810470402240753,
#   0.25884339213371277,
#   2.1651439666748047,
#   0.4039384424686432,
#   1.1772500276565552,
#   -0.16847817599773407,
#   0.9856759309768677,
#   0.17747727036476135,
#   -0.3401942849159241,
#   0.5274795293807983,
#   0.7229041457176208,
#   -0.3253302276134491,
#   0.7680449485778809,
#   -0.5925784111022949,
# ...

# %%
R2 = embeddings.embed_query("hello world")
R2
# Out:
# [-0.7690892815589905,
#  -0.1390518993139267,
#  0.28999921679496765,
#  1.4514001607894897,
#  2.086055040359497,
#  0.2550806999206543,
#  -0.5814754366874695,
#  -0.22437123954296112,
#  1.3218432664871216,
#  -1.1596091985702515,
#  0.04753025248646736,
#  0.08092934638261795,
#  0.0051306476816535,
#  0.9456397294998169,
#  -1.6078474521636963,
#  0.21081675589084625,
#  3.3036088943481445,
#  -0.38705870509147644,
#  0.684038519859314,
#  -1.085428237915039,
#  0.12892639636993408,
#  0.7224303483963013,
#  -1.5754677057266235,
#  -0.8470370173454285,
#  -2.1444969177246094,
#  0.6257835030555725,
#  -0.8562989234924316,
#  0.2684911787509918,
#  2.2042291164398193,
#  -0.3570682406425476,
#  0.6247701644897461,
#  0.4419247806072235,
#  0.6449736952781677,
#  -0.21644601225852966,
#  -0.14526589214801788,
#  0.539030909538269,
#  1.74076509475708,
#  -0.18795707821846008,
#  0.6041951775550842,
#  -1.1086487770080566,
#  1.5186036825180054,
#  -1.2288583517074585,
# ...

# %%
##Document → Loader → Split → Embeddings → Vector Store (FAISS)
from langchain_community.document_loaders import PyPDFLoader

loader = PyPDFLoader("your_file.pdf")
documents = loader.load()

print(len(documents))

# %%
from langchain_community.document_loaders import TextLoader

loader = TextLoader("speech.txt", encoding="utf-8")
documents = loader.load()

print(documents[0].page_content[:200])  # preview
# Out:
# The world must be made safe for democracy. Its peace must be planted upon the tested foundations of political liberty. We have no selfish ends to serve. We desire no conquest, no dominion. We seek no

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=500,
    chunk_overlap=50
)

chunks = text_splitter.split_documents(documents)

print(len(chunks))
# Out:
# 10

# %%
from langchain_community.embeddings import OllamaEmbeddings

embeddings = OllamaEmbeddings(
    model="mxbai-embed-large"
)

# %%
##### ollama pull mxbai-embed-large

# %%
from langchain_community.embeddings import OllamaEmbeddings

embeddings = OllamaEmbeddings(model="mxbai-embed-large")

text = "This is a test document."
query_result = embeddings.embed_query(text)

print(len(query_result))  # should return vector size
# Out:
# 1024
