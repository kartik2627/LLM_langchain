328125, -0.08203125, 0.036865234375, -0.046844482421875, -0.033233642578125, -0.049896240234375, -0.0263671875, -0.0291748046875, -0.01107025146484375, -0.0052337646484375, 0.01488494873046875, -0.08477783203125, -0.022674560546875, -0.01514434814453125, 0.00667572021484375, 0.041656494140625, -0.02752685546875, -0.04840087890625, -0.0271148681640625, 0.01934814453125, -0.0142364501953125, 0.042236328125, -0.005146026611328125, -0.043670654296875, -0.035430908203125, -0.0548095703125, 0.0019283294677734375, 0.00829315185546875, 0.031463623046875, 0.0213775634765625, -0.018035888671875, -0.0141143798828125, -0.040069580078125, -0.01186370849609375, -0.042877197265625, -0.032470703125, -0.042266845703125, 0.036956787109375, -0.0300750732421875, -0.00628662109375, -0.03253173828125, 0.0062408447265625, -0.011871337890625, -0.060638427734375, 0.002105712890625, 0.0059814453125, -0.0046539306640625, 0.04180908203125, 0.01091766357421875, 0.0089263916015625, -0.0162353515625, -0.06689453125, 0.0119171142578125, -0.0112152099609375, 0.036163330078125, 0.018646240234375, -0.0217437744140625, 0.034423828125, 2.8252601623535156e-05, -0.0278778076171875, 0.0113525390625, -0.04571533203125, 0.00833892822265625, 0.0239105224609375, -0.0018358230590820312, -0.022003173828125, 0.031219482421875, -0.049407958984375, -0.01041412353515625, -0.03472900390625, -0.0175323486328125, 0.015472412109375, -0.03277587890625, 0.0303192138671875, 0.033477783203125, 0.0099334716796875, -0.00847625732421875, 0.028045654296875, 0.01227569580078125, -0.031219482421875, 0.019287109375, 0.05230712890625, -0.0208282470703125, -0.038543701171875, 0.03363037109375, -0.0168914794921875, -0.0318603515625, -0.03387451171875, 0.007297515869140625, -0.02593994140625, 0.005580902099609375, -0.004093170166015625, -0.06585693359375, 0.03546142578125, 0.00994110107421875, -0.00724029541015625, 0.055206298828125, -0.01190185546875, 0.0322265625, -0.0322265625, 0.01372528076171875, -0.01019287109375, 0.023223876953125, 0.049774169921875, 0.0064849853515625, -0.023712158203125, 0.0265655517578125, 0.015716552734375, -0.041290283203125, -0.01322174072265625, -0.0016527175903320312, 0.0579833984375, -0.02178955078125, 0.051025390625, 0.00270843505859375, -0.00396728515625, 0.059234619140625, -0. ...

# %%
from langchain_community.document_loaders import  TextLoader
loader = TextLoader("speech.txt")
documents = loader.load()
documents[0].page_content[:100]
# Out:
# 'The world must be made safe for democracy. Its peace must be planted upon the tested foundations of '

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter
text_splitter = RecursiveCharacterTextSplitter(chunk_size=100, chunk_overlap=0)
texts = text_splitter.split_documents(documents)
texts
# Out:
# [Document(metadata={'source': 'speech.txt'}, page_content='The world must be made safe for democracy. Its peace must be planted upon the tested foundations of'),
#  Document(metadata={'source': 'speech.txt'}, page_content='political liberty. We have no selfish ends to serve. We desire no conquest, no dominion. We seek no'),
#  Document(metadata={'source': 'speech.txt'}, page_content='indemnities for ourselves, no material compensation for the sacrifices we shall freely make. We are'),
#  Document(metadata={'source': 'speech.txt'}, page_content='but one of the champions of the rights of mankind. We shall be satisfied when those rights have'),
#  Document(metadata={'source': 'speech.txt'}, page_content='been made as secure as the faith and the freedom of nations can make them.'),
#  Document(metadata={'source': 'speech.txt'}, page_content='Just because we fight without rancor and without selfish object, seeking nothing for ourselves but'),
#  Document(metadata={'source': 'speech.txt'}, page_content='what we shall wish to share with all free peoples, we shall, I feel confident, conduct our'),
#  Document(metadata={'source': 'speech.txt'}, page_content='operations as belligerents without passion and ourselves observe with proud punctilio the'),
#  Document(metadata={'source': 'speech.txt'}, page_content='principles of right and of fair play we profess to be fighting for.'),
#  Document(metadata={'source': 'speech.txt'}, page_content='…'),
#  Document(metadata={'source': 'speech.txt'}, page_content='It will be all the easier for us to conduct ourselves as belligerents in a high spirit of right and'),
#  Document(metadata={'source': 'speech.txt'}, page_content='fairness because we act without animus, not in enmity toward a people or with the desire to bring'),
#  Document(metadata={'source': 'speech.txt'}, page_content='any injury or disadvantage upon them, but only in armed opposition to an irresponsible government'),
#  Document(metadata={'source': 'speech.txt'}, page_content='which has thrown aside all considerations of humanity and of right and is running amuck. We are,'),
#  Document(metadata={'source': 'speech.txt'}, page_content='let me say again, the sincere friends of the German people, and shall desire nothing so much as the'),
#  Document(metadata={'source': 'speech.txt'}, page_content='early reestablishment of intimate relations of mutual advantage between us—however hard it may be'),
#  Document(metadata={'source': 'speech.txt'}, page_content='for them, for the time being, to believe that this is spoken from our hearts.'),
#  Document(metadata={'source': 'speech.txt'}, page_content='We have borne with their present government through all these bitter months because of that'),
#  Document(metadata={'source': 'speech.txt'}, page_content='friendship—exercising a patience and forbearance which would otherwise have been impossible. We'),
#  Document(metadata={'source': 'speech.txt'}, page_content='shall, happily, still have an opportunity to prove that friendship in our daily attitude and'),
#  Document(metadata={'source': 'speech.txt'}, page_content='actions toward the millions of men and women of German birth and native sympathy who live among us'),
#  Document(metadata={'source': 'speech.txt'}, page_content='and share our life, and we shall be proud to prove it toward all who are in fact loyal to their'),
#  Document(metadata={'source': 'speech.txt'}, page_content='neighbors and to the government in the hour of test. They are, most of them, as true and loyal'),
#  Document(metadata={'source': 'speech.txt'}, page_content='Americans as if they had never known any other fealty or allegiance. They will be prompt to stand'),
#  Document(metadata={'source': 'speech.txt'}, page_content='with us in rebuking and restraining the few who may be of a different mind and purpose. If there'),
#  Document(metadata={'source': 'speech.txt'}, page_content='should be disloyalty, it will be dealt with with a firm hand of stern repression; but, if it lifts'),
#  Document(metadata={'source': 'speech.txt'}, page_content='its head at all, it will lift it only here and there and without countenance except from a lawless'),
#  Document(metadata={'source': 'speech.txt'}, page_content='and malignant few.'),
#  Document(metadata={'source': 'speech.txt'}, page_content='It is a distressing and oppressive duty, gentlemen of the Congress, which I have performed in thus'),
#  Document(metadata={'source': 'speech.txt'}, page_content='addressing you. There are, it may be, many months of fiery trial and sacrifice ahead of us. It is a'),
#  Document(metadata={'source': 'speech.txt'}, page_content='fearful thing to lead this great peaceful people into war, into the most terrible and disastrous of'),
#  Document(metadata={'source': 'speech.txt'}, page_content='all wars, civilization itself seeming to be in the balance. But the right is more precious than'),
#  Document(metadata={'source': 'speech.txt'}, page_content='peace, and we shall fight for the things which we have always carried nearest our hearts—for'),
#  Document(metadata={'source': 'speech.txt'}, page_content='democracy, for the right of those who submit to authority to have a voice in their own governments,'),
#  Document(metadata={'source': 'speech.txt'}, page_content='for the rights and liberties of small nations, for a universal dominion of right by such a concert'),
#  Document(metadata={'source': 'speech.txt'}, page_content='of free peoples as shall bring peace and safety to all nations and make the world itself at last'),
#  Document(metadata={'source': 'speech.txt'}, page_content='free.'),
#  Document(metadata={'source': 'speech.txt'}, page_content='To such a task we can dedicate our lives and our fortunes, everything that we are and everything'),
#  Document(metadata={'source': 'speech.txt'}, page_content='that we have, with the pride of those who know that the day has come when America is privileged to'),
#  Document(metadata={'source': 'speech.txt'}, page_content='spend her blood and her might for the principles that gave her birth and happiness and the peace'),
#  Document(metadata={'source': 'speech.txt'}, page_content='which she has treasured. God helping her, she can do no other.')]

# %%
from langchain_openai import OpenAIEmbeddings
from  langchain_community.vectorstores import Chroma
embeddings = OpenAIEmbeddings(model="text-embedding-3-small")
embedding_vectors = embeddings.embed_documents([text.page_content for text in texts])
db  = Chroma.from_documents(texts,embeddings)

# %%
db

# %%
A = db.similarity_search("What is the main topic of the speech?", k=2)

# %%
A
# Out:
# [Document(metadata={'source': 'speech.txt'}, page_content='actions toward the millions of men and women of German birth and native sympathy who live among us'),
#  Document(metadata={'source': 'speech.txt'}, page_content='principles of right and of fair play we profess to be fighting for.')]
