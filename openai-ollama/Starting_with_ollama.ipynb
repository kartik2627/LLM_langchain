# %%
import os
from dotenv import load_dotenv

from langchain_community.llms import Ollama
import streamlit as st
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser

# %%
load_dotenv()

## Langsmith Tracking
os.environ["LANGCHAIN_API_KEY"]=os.getenv("LANGCHAIN_API_KEY")
os.environ["LANGCHAIN_TRACING_V2"]="true"
os.environ["LANGCHAIN_PROJECT"]=os.getenv("LANGCHAIN_PROJECT")

# %%
prompt = ChatPromptTemplate.from_messages(
    [
        ("system","You are a helpful assistant. Please respond to the question asked"),
        ("user","Question:{question}")
    ]
)

# %%
## streamlit framework
st.title("Langchain Demo With Gemma Model")
input_text=st.text_input("What question you have in mind?")


## Ollama Llama2 model
llm=Ollama(model="gemma:2b")
output_parser=StrOutputParser()
chain=prompt|llm|output_parser

if input_text:
    st.write(chain.invoke({"question":input_text}))
# Out:
# 2026-04-15 23:33:07.444 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-15 23:33:08.135
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run c:\Users\Karti\anaconda3\Lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2026-04-15 23:33:08.137 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-15 23:33:08.141 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-15 23:33:08.143 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-15 23:33:08.145 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-15 23:33:08.147 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-15 23:33:08.152 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-15 23:33:08.154 Session state does not function when running a script without `streamlit run`
# 2026-04-15 23:33:08.160 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-15 23:33:08.162 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-15 23:33:08.163 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# C:\Users\Karti\AppData\Local\Temp\ipykernel_16796\1377614211.py:7: LangChainDeprecationWarning: The class `Ollama` was deprecated in LangChain 0.3.1 and will be removed in 1.0.0. An updated version of the class exists in the `langchain-ollama package and should be used instead. To use it run `pip install -U `langchain-ollama` and import as `from `langchain_ollama import OllamaLLM``.
#   llm=Ollama(model="gemma:2b")
